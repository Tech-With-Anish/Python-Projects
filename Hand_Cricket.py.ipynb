# %%
# creaing a hand cricket game with python
import random # we will be using the random function a lot in this game
import sys # mainly will be using the exit function from this module

user_score = 0 # this will be helfull to count the user score
computer_score = 0 # this will be helfull to count the computer score
# first create a function which asks the user if he want's to play

print("===============================================Welcome To Hand Cricket Game===============================================")
print("Rules of This Game:-\n\t1) You will be playing with a Ai Bot\n\t2) You can only choose from 1 to 6 numbers\n\t3)Incase you put a number out of the range and put somthing else you will bee terminated\n\t4)You cannot cheat because This is a programed game")
# writng the rules of the game

# %%
def play_game():
    global game_on # using the global func to glob game_on
    run = True
    # create a while loop if the user input's somthing wrong
    print("\n============================STARTING THE GAME============================")
    while run:
        game_on = input("Do you wanna play? ") # taking user input

        # wrting the control flow logic
        if game_on == 'yes':
            pass # don't do anythin 
        elif game_on == 'no':
            print("Bye!")
            sys.exit() # exits out of the game and ends the program
        else:
            print("I don't know that")
            continue # if the user input's somthing wrong it goes back to closest enclosing loop
        run = False # if the above process has been satisfied the while loop ends or breaks

# create a fucntion which asks the if he wants to be odd or even

# %%
def choose_odd_even():
    global user_choice
    print("\n============================Toss-Time============================")
    while game_on == "yes":
        user_choice = input("Do you wanna be odd or even? ") # asking the user if he wants to be odd or even
        # the control flow logic 

        if user_choice == 'even':
            print("Your Even and The Computer is Odd")
        elif user_choice == 'odd':
            print("Your odd and The Computer is Even")
        else:
            print("I don't know that")
            # if the user inputs something wrong it goes back to the closest enclosing loop
            continue
        break # if the condition is satisfies then it breaks out of the loop
    
# now we need to write who has won the toss and if want's to do bating or bowling

# %%
def toss_winner():
    global ask_toss_number, computer_toss_number, add_tnumbers , winner_choice# global the choose_toss variable
    
    run = True
    while run: # we are using the except beause if the user input an string it's going to lead to valueerror to prevent that we will be using this
        try:
            computer_toss_number = random.randint(1, 6) # taking the computer number from 1 to 6
            ask_toss_number = int(input("Enter a Number from (1 to 6)?  ")) # taking the user input
            # control flow logic
            
        except ValueError:
            print("You have not put an number\nstart the game again")
            sys.exit()

        else:
            # user's game logic
            if ask_toss_number in range(1, 6+1): # if the user inputed number is in range do this 
                add_tnumbers = ask_toss_number + computer_toss_number
                if add_tnumbers % 2 == 0 and user_choice == 'even':
                    print(f"You have choosen {ask_toss_number}")
                    print(f"Computer has choosen {computer_toss_number}")
                    print(f"You have won the toss {add_tnumbers}")
                    winner_choice = input("batting or balling(write the same)? ") # asking the user if he want's to bat first or ball firs
                    if winner_choice == 'batting':
                        print("You will be batting and the computer will be balling ")
                        bat_first()
                        ball_second()
                    elif winner_choice == "balling":
                        print("you will be balling and the computer will be bating")
                        ball_first()
                        bat_second()
                    else:
                        sys.exit()

                elif add_tnumbers % 2 == 1 and user_choice == 'odd':
                        print(f"You have choosen {ask_toss_number}")
                        print(f"Computer has choosen {computer_toss_number}")
                        print(f"You have won The toss {add_tnumbers}")
                        winner_choice = input("batting or balling(write the same)? ")
                        # asking the user if he want's to bat first or ball first
                        if winner_choice == 'batting':
                            print("You will be batting and the computer will be balling ")
                            bat_first()
                            ball_second()

                        elif winner_choice == 'balling':
                            print("you will be balling and the computer will be bating")
                            ball_first()
                            bat_second()
                        else:
                            sys.exit()
        
                # comptuer's game logic
                else:
                    computer_win_choose = ['batting', 'balling']
                    random_com_choose = random.choice(computer_win_choose)
                    print(F"You have put {ask_toss_number}")
                    print(F'The Computer has put {computer_toss_number}')
                    print(f"You have lost the toss {add_tnumbers}")
                    if random_com_choose == 'batting':
                        print("The computer has choosen to bat first")
                        ball_first()
                        bat_second()
                    elif random_com_choose == 'balling':
                        print("The computer has choosen to ball first")
                        bat_first()
                        ball_second()
            elif ask_toss_number not in range(1, 6+1):
                print("number is not in range ")
                continue
    # create a fucntion which asks the user if he wants to bat or ball first# if this constion if false then it is gone be computer turn to choose what it whants

# %%
def bat_first():
    global user_score, user_batting, user_minus_runs# we are globlizing these local variables

    run = True 
    print("\n===================User Batting===================")
    try :
        while run:
            computer_balling_batting = random.randint(1,6) # the computer is gone pick a random number to see if it can out the user
            user_batting = int(input("Enter your run(1 to 6)?"))
            user_score += user_batting # everytime the user inputs a number it adds it 
            user_minus_runs = user_score - user_batting
            # control flow logic
            if user_batting in range(1,6+1):
                if user_batting == computer_balling_batting:
                    print(F"You have hit {computer_balling_batting}")
                    print(F"The computer has balled {computer_balling_batting}")
                    print(F"You are out!!\nScore : {user_minus_runs}")
                    run = False
                if user_batting != computer_balling_batting:
                        print(F"You have hit {user_batting}")
                        print(F"The computer has balled {computer_balling_batting}")
                        print(f"Your score {user_score}")
        
            elif user_batting not in range(1, 6+1):
                print("You are cheating please follow the rules?\nThe match has been terminated")
                sys.exit()
                
    except ValueError:
        print(f"You are cheating can only put number")
        sys.exit()

# %%
# we need to a funciton which handles if the user is batting second
def bat_second():
    global user_score, computer_score, user_batting
    print("\n===================User Batting===================")
    run = True
    while run:
        try:
            computer_balling_batting = random.randint(1,6)
            batting_again = int(input("Enter your run(1 to 6)? "))
            user_score += batting_again
            user2_minus_runs = user_score - batting_again
            if batting_again in range(1, 6+1):
                if batting_again == computer_balling_batting:
                    print(F"You have hit {batting_again}")
                    print(F"The computer has balled {computer_balling_batting}")
                    print(F"Your score :  {user2_minus_runs}")
                    print(f"You have lost by { com2_minus_runs - user2_minus_runs} runs")
                    sys.exit()
                
                if user_score > com2_minus_runs:
                    print(F"Computer has balled {computer_balling_batting}")
                    print(F"Congrats!!! You have won the match by {user_score - com2_minus_runs} runs")
                    sys.exit()
                
                else:
                    print(f"The computer has balled {computer_balling_batting}")
                    print(F"Your Score : {user_score}")
                        
            
            elif user_batting not in range(1, 6+1):
                print("You are cheating please follow the rules?\nThe match has been terminated")
                sys.exit()
                
        except ValueError:
            print(f"You are cheating can only put numbers not this {batting_again}")
            sys.exit()

# %%
# we need to create if the user chooses bowling 

def ball_first():
    global computer_score, user_balling, com2_minus_runs
    print("\n==========================Computer Batting==========================")
    run = True
    try:
        while run:
            computer_balling_batting = random.randint(1,6)
            user_balling = int(input("Enter your ball run(1 to 6)? "))
            computer_score += computer_balling_batting
            com2_minus_runs = computer_score - computer_balling_batting
            if user_balling in range(1, 6+1):
                if user_balling == computer_balling_batting:
                    print(F'The computer has hit {computer_balling_batting}')
                    print(F'The Computer score is {com2_minus_runs}')
                    print(F'The Computer is out!!!')
                    run = False
                if user_balling != computer_balling_batting:
                        print(F"You have balled {user_balling}")
                        print(F"The computer has hit {computer_balling_batting}")
                        print(f"Computer Score : {computer_score}")
            elif user_balling not in range(1, 6+1):
                print("You are cheating please follow the rules?\nThe match has been terminated")
                sys.exit()
    except ValueError:
        print(f"You are cheating can only put numbers not this {user_batting} ")
        sys.exit()

# %%
def ball_second():
    global computer_score, user_score, user_balling_second, com_minus_runs
    print("\n==========================Computer Batting==========================")
    run = True
    try:
        while run :
            user_balling_second = int(input("Enter your ball run(1 to 6)? "))
            computer_balling_batting = random.randint(1,6)
            computer_score += computer_balling_batting
            com_minus_runs = computer_score - computer_balling_batting
            if user_balling_second in range(1,6+1):
                if user_balling_second == computer_balling_batting:
                    print(f"The computer has hit : {computer_balling_batting}")
                    print(F"The computer score :  {com_minus_runs}")
                    print(F"The computer has lost the match by {user_minus_runs - com_minus_runs} runs\nYou have won the match :)")
                    sys.exit()
                if user_balling_second != computer_balling_batting:
                    if computer_score > user_minus_runs:
                        print(F"The Computer score : {computer_score}")
                        print(F"You have lost the match by {computer_score - user_minus_runs} runs ")
                        print(F"The computer has won the match")
                        sys.exit()
                    else:
                        print(f"The  Computer has hit {computer_balling_batting}")
                        print(F"The computer's score is {computer_score}")
            elif user_batting not in range(1, 6+1):
                print("You are cheating please follow the rules?\nThe match has been terminated")
                sys.exit()

    except ValueError:
        print(f"You are cheating can only put numbers not this {user_batting} ")
        sys.exit()

# %%
def main():
    play_game()
    choose_odd_even()
    toss_winner()

# %%
if __name__ == '__main__':
    main()
# it was really fun making this hand cricket game :)
