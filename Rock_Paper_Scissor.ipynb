# %%
import random # we will be importing the random
# we are creating a rock , paper scissor game using pythons opp
class Rock_Paper_Scissor: # creating a class called rock paper scissor
    
    def __init__(self, wins, losses, ties, computer_wins, computer_losses, computer_ties, user2_wins, user2_losses, user2_ties):
        self.wins = wins
        self.losses = losses
        self.ties = ties
        self.computer_wins = computer_wins
        self.computer_losses = computer_losses
        self.computer_ties = computer_ties
        self.user2_wins = user2_wins
        self.user2_losses = user2_losses
        self.user2_ties = user2_ties
        
    def start_game(self):
        run = True
        print("=======================================ROCK PAPER SCISSOR=======================================")
        while run:
            play_game = input("Do You wanna play? ")
            self.play_game = play_game
            if self.play_game == 'yes':
                pass
            elif self.play_game == 'no':
                print("Bye ")
                sys.exit()
            else:
                print("I don't know that")
                continue
            run = False


    def player_vs_Ai(self):
        print("\n========================================Ai vs Player========================================")
        while self.play_game == 'yes':
            print(f'''===USER===                                                                       ===Computer===
WINS : {self.wins}                                                                           WINS = {self.computer_wins}
LOSSES : {self.losses}                                                                         LOSSES = {self.computer_losses}
TIES : {self.ties}                                                                           TIES = {self.computer_ties}''')
            
            # the user logic 
            weapons_inputs = ["rock", 'paper', 'scissor']
            self.weapons_inputs = weapons_inputs
            choose_weapon = input("Choose Your Weapon ?")
            if choose_weapon in self.weapons_inputs:
                if choose_weapon == 'rock':
                    print("The user has used the rock weapon")
                elif choose_weapon == 'paper':
                    print("The user has used the paper weapon")
                elif choose_weapon == 'scissor':
                    print("The user has used the scissor weapon")
                else:
                    print("I don't know that")
                    continue
            elif choose_weapon == "q":
                break
            # the computer logic
            computer_weapons = ["rock", "paper", "scissor"]
            random_computer_weapon = random.choice(computer_weapons)
            if random_computer_weapon == "rock":
                print("The computer has used rock weapon")
            elif random_computer_weapon == 'paper':
                print("The computer has used paper weapon")
            elif random_computer_weapon == 'scissor':
                print("The computer has used scissor weapon")
            # here is where the game logic begins 
            if choose_weapon == random_computer_weapon:
                print("That's a Tie")
                self.ties += 1
                self.computer_ties += 1
            elif choose_weapon == "rock" and random_computer_weapon == 'paper':
                print("Ai Wins")
                self.computer_wins += 1
                self.losses += 1
            elif choose_weapon == "paper" and random_computer_weapon == 'rock':
                print("player Wins")
                self.wins += 1
                self.computer_losses += 1
            
            elif choose_weapon == "scissor" and random_computer_weapon == 'paper':
                print("player Wins")
                self.wins += 1
                self.computer_losses += 1
                
            elif choose_weapon == "paper" and random_computer_weapon == 'scissor':
                print("Ai Wins")
                self.computer_wins += 1
                self.losses += 1
            elif choose_weapon == "rock" and random_computer_weapon == 'scissor':
                print("player Wins")
                self.wins += 1
                self.computer_losses += 1
            elif choose_weapon == "scissor" and random_computer_weapon == 'rock':
                print("Ai Wins")
                self.computer_wins += 1
                self.losses += 1
                
 
            
game = Rock_Paper_Scissor(0, 0, 0, 0, 0, 0, 0, 0, 0)
game.start_game()
game.player_vs_Ai()
